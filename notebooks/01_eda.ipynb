# %%
import pandas as pd

# %%
df=pd.read_stata('../data/raw/P2P_Macro_Data.dta')

# %%
df= pd.read_parquet('../data/raw/P2P_Macro_Data.parquet')

# %%
print("Shape:", df.shape)
print("\nbadloan distribution:")
print(df['badloan'].value_counts())
print(df['badloan'].value_counts(normalize=True).round(3))

print("\nMissing values (top 20):")
print(df.isnull().sum().sort_values(ascending=False).head(20))

print("\nDate range:")
print(df['issue_daily'].min(), "→", df['issue_daily'].max())
# Out:
# Shape: (2703430, 195)
#
# badloan distribution:
# badloan
# 0.0    2486808
# 1.0     216622
# Name: count, dtype: int64
# badloan
# 0.0    0.92
# 1.0    0.08
# Name: proportion, dtype: float64
#
# Missing values (top 20):
# url                               2703430
# verification_status_joint         2703430
# revol_bal_joint                   2526829
# sec_app_open_act_il               2526828
# dti_joint                         2514226
# annual_inc_joint                  2514222
# mths_since_last_record            2294084
# lognum_accts_ever_120_pd          2097855
# mths_since_recent_bc_dlq          2081980
# mths_since_last_major_derog       2010592
# mths_since_recent_revol_delinq    1819855
# mths_since_last_delinq            1402509
# open_act_il                       1229615
# il_util                           1067810
# logpercent_bc_gt_75                814961
# inq_last_12m                       795480
# open_acc_6m                        795480
# inq_fi                             795480
# total_cu_tl                        795480
# total_bal_il                       795480
# dtype: int64
#
# Date range:
# 2012-08-01 00:00:00 → 2019-12-01 00:00:00

# %%
df.columns.tolist()
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'total_bal_il',
#  'il_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'open_act_il',
#  'sec_app_open_act_il',
#  'issue_date',
#  'last_date',
#  'region',
#  'subregion',
#  'earnings',
#  'employment',
#  'labor_force',
#  'Muni',
#  'muni_m',
#  'FEDFUNDS',
#  'internetuser',
#  'internetuserprop',
#  'empl_exp_prop',
#  'empl_expan',
#  'empl_birth',
#  'empl_birth_per',
#  'new_bus',
#  'new_bus_per',
#  'popestimate',
#  'dem',
#  'rep',
#  'red',
#  'christianity',
#  'religiousity',
#  'unemployment',
#  'unem_rate',
#  'gdpindex',
#  'gdpreal',
#  'gdpcontrib',
#  'cpi',
#  'cpiregion',
#  'inf',
#  'gdppercap',
#  'des_length',
#  'application_type_',
#  'initial_list_status_',
#  'purpose_',
#  'pymnt_plan_',
#  'verification_status_',
#  'home_ownership_',
#  'emp_length_',
#  'grade_',
#  'sub_grade_',
#  'term_',
#  'loan_status_',
#  'badloan',
#  'rankloan_status_',
#  'logfunded_amnt',
#  'logannual_inc',
#  'logdti',
#  'logtotal_acc',
#  'logmo_sin_old_il_acct',
#  'logmo_sin_rcnt_tl',
#  'lognum_accts_ever_120_pd',
#  'logpct_tl_nvr_dlq',
#  'logpercent_bc_gt_75',
#  'logtot_hi_cred_lim',
#  'logearnings',
#  'logemployment',
#  'loglabor_force',
#  'logfinanceuser',
#  'logsocialnetworkuser',
#  'loginternetuser',
#  'logempl_expan',
#  'logempl_birth',
#  'lognew_bus',
#  'logpopestimate',
#  'logunemployment',
#  'loggdppercap',
#  'state',
#  'muni_points',
#  'muni_6m',
#  'inf_6m',
#  'loan_vol',
#  'loanmedian',
#  'median_dummy',
#  'daily_date',
#  'quarter',
#  'month',
#  'year',
#  'CPIUS',
#  'logCPIUS',
#  'infUS',
#  'logloan_vol',
#  'loan_status_5',
#  'meanopen_acc',
#  'FED_lag6',
#  'riskprem',
#  'loan_vol6m',
#  'loglvol_6m',
#  'issue_daily',
#  'issue_year',
#  'loan6m_median',
#  'loan_sum']

# %%
fico_check = [c for c in df.columns if 'fico' in c.lower()]
print("FICO columns:", fico_check)
# Out:
# FICO columns: []

# %%
# Check if baselinesample column exists
print('baselinesample' in df.columns)

# If it does:
if 'baselinesample' in df.columns:
    print(df['baselinesample'].value_counts())
    print("Baseline sample size:", df[df['baselinesample']==1].shape)
# Out:
# False

# %%
#SANITY CHECK
# Check 1: does baselinesample exist?
print("baselinesample exists:", 'baselinesample' in df.columns)

# Check 2: default rate by year
print("\nDefault rate by year:")
print(df.groupby('issue_year')['badloan'].mean().round(3))

# Check 3: default rate by grade
print("\nDefault rate by grade:")
print(df.groupby('grade_')['badloan'].mean().sort_values(ascending=False).round(3))

# Check 4: pymnt_plan variance (we discussed this might be near-zero)
print("\npymnt_plan distribution:")
print(df['pymnt_plan'].value_counts())
# Out:
# baselinesample exists: False
#
# Default rate by year:
# issue_year
# 2012.0    0.155
# 2013.0    0.150
# 2014.0    0.154
# 2015.0    0.185
# 2016.0    0.048
# 2017.0    0.077
# 2018.0    0.021
# 2019.0    0.025
# Name: badloan, dtype: float32
#
# Default rate by grade:
# grade_
# G    0.316
# F    0.287
# E    0.218
# D    0.131
# C    0.090
# B    0.052
# A    0.020
# Name: badloan, dtype: float32
#
# pymnt_plan distribution:
# pymnt_plan
# n    2703105
# y        325
# Name: count, dtype: int64
# C:\Users\Divyansh\AppData\Local\Temp\ipykernel_51780\879586789.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('grade_')['badloan'].mean().sort_values(ascending=False).round(3))

# %%
import sys
sys.path.append('..')  # so Python can find the src folder

from src.data.preprocess import run_preprocessing

df_clean = run_preprocessing()
# Out:
# 2026-03-16 20:09:24 — src.data.preprocess — INFO — ==================================================
# 2026-03-16 20:09:24 — src.data.preprocess — INFO — PREPROCESSING PIPELINE STARTED
# 2026-03-16 20:09:24 — src.data.preprocess — INFO — ==================================================
# 2026-03-16 20:09:24 — src.data.preprocess — INFO — Loading from parquet cache...
# 2026-03-16 20:09:30 — src.data.preprocess — INFO — Loaded raw data: (2703430, 195)
# 2026-03-16 20:09:33 — src.data.preprocess — INFO — Dropped 16 leakage columns: ['total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'out_prncp', 'out_prncp_inv', 'last_pymnt_amnt', 'last_pymnt_d', 'next_pymnt_d', 'loan_status', 'loan_status_', 'loan_status_5', 'rankloan_status_']
# 2026-03-16 20:09:37 — src.data.preprocess — INFO — Dropped 27 useless/redundant columns
# 2026-03-16 20:09:37 — src.data.preprocess — WARNING — Found 2 fully null columns: ['url', 'verification_status_joint']
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — Filtered 0 ambiguous rows — 2,703,430 remain
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — mths_since_last_delinq: filled 1,402,509 nulls with 999 (never delinquent)
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — mths_since_recent_bc: filled 28,608 nulls with 999 (never delinquent)
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — mths_since_recent_inq: filled 303,703 nulls with 999 (never delinquent)
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — il_util: filled 1,067,810 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — open_acc_6m: filled 795,480 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — inq_last_12m: filled 795,480 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — total_bal_il: filled 795,480 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — total_cu_tl: filled 795,480 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — inq_fi: filled 795,480 nulls with 0
# 2026-03-16 20:09:38 — src.data.preprocess — INFO — open_act_il: filled 1,229,615 nulls with 0
# 2026-03-16 20:09:39 — src.data.preprocess — INFO — num_tl_120dpd_2m: filled 90,484 nulls with 0
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — revol_util: filled 2,161 nulls with median (0.4880)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — bc_open_to_buy: filled 30,409 nulls with median (6084.0000)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — bc_util: filled 31,782 nulls with median (57.9000)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — mo_sin_old_rev_tl_op: filled 1 nulls with median (162.0000)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — mo_sin_rcnt_rev_tl_op: filled 1 nulls with median (9.0000)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — num_rev_accts: filled 1 nulls with median (12.0000)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — Muni: filled 38,376 nulls with median (0.0255)
# 2026-03-16 20:09:40 — src.data.preprocess — INFO — logmo_sin_old_il_acct: filled 82,127 nulls with median (4.8675)
# 2026-03-16 20:09:41 — src.data.preprocess — INFO — logmo_sin_rcnt_tl: filled 42,765 nulls with median (1.7918)
# 2026-03-16 20:09:41 — src.data.preprocess — INFO — logsocialnetworkuser: filled 163 nulls with median (14.8115)
# 2026-03-16 20:09:44 — src.data.preprocess — INFO — All missing values resolved
# 2026-03-16 20:09:44 — src.data.preprocess — INFO — ==================================================
# 2026-03-16 20:09:44 — src.data.preprocess — INFO — PREPROCESSING COMPLETE — Final shape: (2703430, 152)
# 2026-03-16 20:09:44 — src.data.preprocess — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-16 20:09:44 — src.data.preprocess — INFO — ==================================================
# 2026-03-16 20:10:01 — src.data.preprocess — INFO — Saved processed data to C:\college\PROJECTS\ML\Loan-Risk-Intelligence\data\processed\features.parquet

# %%
import os

# Check if the current directory is 'notebooks'. If so, move up one level to the project root.
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

print("Current working directory:", os.getcwd())

import sys
sys.path.append('..')  # so Python can find the src folder
from src.data.preprocess import run_preprocessing
from src.features.build_features import build_features

# Load preprocessed data
df_clean = pd.read_parquet('data/processed/features.parquet')

# Build features
X, y = build_features(df_clean)

print(X.shape)
print(X.columns.tolist())
print(y.value_counts())
# Out:
# Current working directory: c:\college\PROJECTS\ML\Loan-Risk-Intelligence
# 2026-03-16 20:10:06 — src.features.build_features — INFO — ==================================================
# 2026-03-16 20:10:06 — src.features.build_features — INFO — FEATURE ENGINEERING STARTED
# 2026-03-16 20:10:06 — src.features.build_features — INFO — ==================================================
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Step 1: Encoding categorical + borrower categorical features
# 2026-03-16 20:10:06 — src.features.build_features — INFO — grade_: category -> int codes (7 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — term_: category -> int codes (2 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — purpose_: category -> int codes (13 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — application_type_: category -> int codes (5 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — initial_list_status_: category -> int codes (2 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — emp_length_: category -> int codes (12 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — home_ownership_: category -> int codes (6 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — verification_status_: category -> int codes (3 unique values)
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Step 2: Residualizing macro features against time
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Residualized: muni_6m -> muni_6m_resid
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Residualized: FED_lag6 -> FED_lag6_resid
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Residualized: CPIUS -> CPIUS_resid
# 2026-03-16 20:10:06 — src.features.build_features — INFO — Residualized: FEDFUNDS -> FEDFUNDS_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: inf -> inf_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: inf_6m -> inf_6m_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: muni_points -> muni_points_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: riskprem -> riskprem_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: cpi -> cpi_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: logunemployment -> logunemployment_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: logearnings -> logearnings_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Residualized: gdpcontrib -> gdpcontrib_resid
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Step 3: Engineering interaction features
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Created: dti_x_unemployment (using logunemployment_resid)
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Created: real_interest_rate
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Created: loan_to_income
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Created: util_x_delinq
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Created: fed_x_term
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Step 4: Selecting final feature matrix
# 2026-03-16 20:10:07 — src.features.build_features — INFO — LOAN: 28/28 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — BORROWER: 5/5 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — MACRO: 16/16 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — CATEGORICAL: 5/5 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — TIME: 1/1 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — INTERACTION: 5/5 features present
# 2026-03-16 20:10:07 — src.features.build_features — INFO — Final feature count: 60
# 2026-03-16 20:10:08 — src.features.build_features — INFO — Step 5: Enforcing numeric dtypes
# 2026-03-16 20:10:08 — src.features.build_features — INFO — All 60 features verified numeric — safe for XGBoost/PyTorch
# 2026-03-16 20:10:08 — src.features.build_features — INFO — Feature matrix shape: (2703430, 60)
# 2026-03-16 20:10:08 — src.features.build_features — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-16 20:10:08 — src.features.build_features — INFO — FEATURE ENGINEERING COMPLETE
# (2703430, 60)
# ['logfunded_amnt', 'int_rate', 'installment', 'inq_last_6mths', 'open_acc', 'logtotal_acc', 'pub_rec', 'des_length', 'logpct_tl_nvr_dlq', 'logtot_hi_cred_lim', 'revol_util', 'revol_bal', 'delinq_2yrs', 'mths_since_last_delinq', 'mths_since_recent_inq', 'mths_since_recent_bc', 'acc_open_past_24mths', 'mort_acc', 'pub_rec_bankruptcies', 'tax_liens', 'acc_now_delinq', 'num_tl_90g_dpd_24m', 'pct_tl_nvr_dlq', 'tot_cur_bal', 'avg_cur_bal', 'bc_util', 'num_actv_bc_tl', 'num_actv_rev_tl', 'logannual_inc', 'logdti', 'emp_length_', 'home_ownership_', 'verification_status_', 'muni_6m_resid', 'FED_lag6_resid', 'CPIUS_resid', 'FEDFUNDS_resid', 'inf_resid', 'inf_6m_resid', 'muni_points_resid', 'riskprem_resid', 'cpi_resid', 'logunemployment_resid', 'logearnings_resid', 'gdpcontrib_resid', 'loglabor_force', 'logempl_birth', 'lognew_bus', 'loginternetuser', 'grade_', 'term_', 'purpose_', 'application_type_', 'initial_list_status_', 'issue_year', 'dti_x_unemployment', 'real_interest_rate', 'loan_to_income', 'util_x_delinq', 'fed_x_term']
# badloan
# 0.0    2486808
# 1.0     216622
# Name: count, dtype: int64

# %%
from src.models.train_xgboost import run_xgboost_training

model = run_xgboost_training()
# Out:
# 2026-03-16 19:41:39 — src.models.train_xgboost — INFO — Loading processed data...
# 2026-03-16 19:41:41 — src.features.build_features — INFO — ==================================================
# 2026-03-16 19:41:41 — src.features.build_features — INFO — FEATURE ENGINEERING STARTED
# 2026-03-16 19:41:41 — src.features.build_features — INFO — ==================================================
# 2026-03-16 19:41:41 — src.features.build_features — INFO — Step 1: Encoding categorical + borrower categorical features
# 2026-03-16 19:41:41 — src.features.build_features — INFO — grade_: category -> int codes (7 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — term_: category -> int codes (2 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — purpose_: category -> int codes (13 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — application_type_: category -> int codes (5 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — initial_list_status_: category -> int codes (2 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — emp_length_: category -> int codes (12 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — home_ownership_: category -> int codes (6 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — verification_status_: category -> int codes (3 unique values)
# 2026-03-16 19:41:41 — src.features.build_features — INFO — Step 2: Residualizing macro features against time
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: muni_6m -> muni_6m_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: FED_lag6 -> FED_lag6_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: CPIUS -> CPIUS_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: FEDFUNDS -> FEDFUNDS_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: inf -> inf_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: inf_6m -> inf_6m_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: muni_points -> muni_points_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: riskprem -> riskprem_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: cpi -> cpi_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: logunemployment -> logunemployment_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: logearnings -> logearnings_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Residualized: gdpcontrib -> gdpcontrib_resid
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Step 3: Engineering interaction features
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Created: dti_x_unemployment (using logunemployment_resid)
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Created: real_interest_rate
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Created: loan_to_income
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Created: util_x_delinq
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Created: fed_x_term
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Step 4: Selecting final feature matrix
# 2026-03-16 19:41:42 — src.features.build_features — INFO — LOAN: 28/28 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — BORROWER: 5/5 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — MACRO: 16/16 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — CATEGORICAL: 5/5 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — TIME: 1/1 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — INTERACTION: 5/5 features present
# 2026-03-16 19:41:42 — src.features.build_features — INFO — Final feature count: 60
# 2026-03-16 19:41:45 — src.features.build_features — INFO — Step 5: Enforcing numeric dtypes
# 2026-03-16 19:41:45 — src.features.build_features — INFO — All 60 features verified numeric — safe for XGBoost/PyTorch
# 2026-03-16 19:41:45 — src.features.build_features — INFO — Feature matrix shape: (2703430, 60)
# 2026-03-16 19:41:45 — src.features.build_features — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-16 19:41:45 — src.features.build_features — INFO — FEATURE ENGINEERING COMPLETE
# 2026-03-16 19:41:46 — src.models.train_xgboost — INFO — Train size: 2,162,744 | Test size: 540,686
# 2026-03-16 19:41:46 — src.models.train_xgboost — INFO — Train target rate: 0.094 | Test target rate: 0.024
# 2026-03-16 19:41:46 — src.models.train_xgboost — INFO — Class distribution — Negative: 1,959,292 | Positive: 203,452
# 2026-03-16 19:41:46 — src.models.train_xgboost — INFO — scale_pos_weight set to: 9.6302
# 2026-03-16 19:41:48 — src.models.train_xgboost — INFO — Running TimeSeriesSplit cross-validation...
# 2026-03-16 19:42:16 — src.models.train_xgboost — INFO — Fold 1 — AUC-ROC: 0.7460 | AUC-PR: 0.4051 | Brier: 0.2265
# 2026-03-16 19:42:28 — src.models.train_xgboost — INFO — Fold 2 — AUC-ROC: 0.8597 | AUC-PR: 0.3739 | Brier: 0.2761
# 2026-03-16 19:43:23 — src.models.train_xgboost — INFO — Fold 3 — AUC-ROC: 0.8608 | AUC-PR: 0.3664 | Brier: 0.1484
# 2026-03-16 19:45:15 — src.models.train_xgboost — INFO — Fold 4 — AUC-ROC: 0.8763 | AUC-PR: 0.3109 | Brier: 0.1481
# 2026-03-16 19:47:10 — src.models.train_xgboost — INFO — Fold 5 — AUC-ROC: 0.9525 | AUC-PR: 0.3719 | Brier: 0.0405
# 2026-03-16 19:47:10 — src.models.train_xgboost — INFO —
# CV Summary — AUC-ROC: 0.8591 ± 0.0661 | AUC-PR: 0.3657 ± 0.0305 | Brier: 0.1679 ± 0.0802
# 2026-03-16 19:47:10 — src.models.train_xgboost — INFO — Training final model on full training set...
# [0]	validation_0-auc:0.23909
# [100]	validation_0-auc:0.68721
# [200]	validation_0-auc:0.70221
# [300]	validation_0-auc:0.70608
# [400]	validation_0-auc:0.70582
# [412]	validation_0-auc:0.70489
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO —
# ========================================
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO — EVALUATION — TEST
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO — AUC-ROC:     0.7073
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO — AUC-PR:      0.0656
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO — Brier Score: 0.1779
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO —
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9866    0.7352    0.8426    527516
#          1.0     0.0537    0.6015    0.0986     13170
#
#     accuracy                         0.7320    540686
#    macro avg     0.5202    0.6684    0.4706    540686
# weighted avg     0.9639    0.7320    0.8245    540686
#
# 2026-03-16 19:49:07 — src.models.train_xgboost — INFO —
# Top 10 features:
#            feature  importance
# 35     CPIUS_resid    0.269224
# 36  FEDFUNDS_resid    0.123470
# 49          grade_    0.100442
# 34  FED_lag6_resid    0.088759
# 33   muni_6m_resid    0.038866
# 40  riskprem_resid    0.036935
# 54      issue_year    0.030484
# 1         int_rate    0.024879
# 50           term_    0.024642
# 41       cpi_resid    0.023098
# 2026/03/16 19:49:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026-03-16 19:49:24 — src.models.train_xgboost — INFO — Model saved to data\outputs\xgb_model.json
# 2026-03-16 19:49:24 — src.models.train_xgboost — INFO — MLflow run ID: 8689cf396c004d5cb17dbcfd190d0d54
# 2026-03-16 19:49:30 — src.models.train_xgboost — INFO — All outputs saved. XGBoost training complete.

# %%
import pandas as pd
from src.utils.config import get_project_root

outputs = get_project_root() / "data/outputs"
importance_df = pd.read_csv(outputs / "xgb_feature_importance.csv")
print(importance_df.head(15).to_string())
# Out:
#               feature  importance
# 0         CPIUS_resid    0.269224
# 1      FEDFUNDS_resid    0.123470
# 2              grade_    0.100442
# 3      FED_lag6_resid    0.088759
# 4       muni_6m_resid    0.038866
# 5      riskprem_resid    0.036935
# 6          issue_year    0.030484
# 7            int_rate    0.024879
# 8               term_    0.024642
# 9           cpi_resid    0.023098
# 10  muni_points_resid    0.022183
# 11         fed_x_term    0.019112
# 12  application_type_    0.014892
# 13          inf_resid    0.012123
# 14    home_ownership_    0.009352

# %%
from src.models.train_nn import run_nn_training

model, y_prob_nn = run_nn_training()
# Out:
# 2026-03-16 20:10:16 — src.models.train_nn — INFO — GPU: NVIDIA GeForce RTX 3060 Laptop GPU | VRAM: 6.0GB
# INFO:src.models.train_nn:GPU: NVIDIA GeForce RTX 3060 Laptop GPU | VRAM: 6.0GB
# 2026-03-16 20:10:16 — src.models.train_nn — INFO — Loading train/test splits from XGBoost run...
# INFO:src.models.train_nn:Loading train/test splits from XGBoost run...
# 2026-03-16 20:10:17 — src.models.train_nn — INFO — Scaling features...
# INFO:src.models.train_nn:Scaling features...
# 2026-03-16 20:10:20 — src.models.train_nn — INFO — Scaler saved
# INFO:src.models.train_nn:Scaler saved
# 2026-03-16 20:10:21 — src.models.train_nn — INFO — pos_weight: 9.6302 (raw) -> 5.0000 (capped at 5.0)
# INFO:src.models.train_nn:pos_weight: 9.6302 (raw) -> 5.0000 (capped at 5.0)
# 2026-03-16 20:11:09 — src.models.train_nn — INFO — Epoch 001 | Loss: 0.7040 | AUC-ROC: 0.6865 | AUC-PR: 0.0540 | Brier: 0.0246 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 001 | Loss: 0.7040 | AUC-ROC: 0.6865 | AUC-PR: 0.0540 | Brier: 0.0246 | LR: 3.00e-04
# 2026-03-16 20:11:09 — src.models.train_nn — INFO —   -> New best AUC: 0.6865 (saved checkpoint)
# INFO:src.models.train_nn:  -> New best AUC: 0.6865 (saved checkpoint)
# 2026-03-16 20:11:44 — src.models.train_nn — INFO — Epoch 002 | Loss: 0.6042 | AUC-ROC: 0.6870 | AUC-PR: 0.0565 | Brier: 0.0244 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 002 | Loss: 0.6042 | AUC-ROC: 0.6870 | AUC-PR: 0.0565 | Brier: 0.0244 | LR: 3.00e-04
# 2026-03-16 20:11:44 — src.models.train_nn — INFO —   -> New best AUC: 0.6870 (saved checkpoint)
# INFO:src.models.train_nn:  -> New best AUC: 0.6870 (saved checkpoint)
# 2026-03-16 20:12:16 — src.models.train_nn — INFO — Epoch 003 | Loss: 0.5782 | AUC-ROC: 0.6912 | AUC-PR: 0.0622 | Brier: 0.0268 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 003 | Loss: 0.5782 | AUC-ROC: 0.6912 | AUC-PR: 0.0622 | Brier: 0.0268 | LR: 3.00e-04
# 2026-03-16 20:12:16 — src.models.train_nn — INFO —   -> New best AUC: 0.6912 (saved checkpoint)
# INFO:src.models.train_nn:  -> New best AUC: 0.6912 (saved checkpoint)
# 2026-03-16 20:12:51 — src.models.train_nn — INFO — Epoch 004 | Loss: 0.5645 | AUC-ROC: 0.6795 | AUC-PR: 0.0622 | Brier: 0.0388 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 004 | Loss: 0.5645 | AUC-ROC: 0.6795 | AUC-PR: 0.0622 | Brier: 0.0388 | LR: 3.00e-04
# 2026-03-16 20:13:24 — src.models.train_nn — INFO — Epoch 005 | Loss: 0.5578 | AUC-ROC: 0.6710 | AUC-PR: 0.0625 | Brier: 0.0420 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 005 | Loss: 0.5578 | AUC-ROC: 0.6710 | AUC-PR: 0.0625 | Brier: 0.0420 | LR: 3.00e-04
# 2026-03-16 20:13:57 — src.models.train_nn — INFO — Epoch 006 | Loss: 0.5511 | AUC-ROC: 0.6825 | AUC-PR: 0.0639 | Brier: 0.0430 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 006 | Loss: 0.5511 | AUC-ROC: 0.6825 | AUC-PR: 0.0639 | Brier: 0.0430 | LR: 3.00e-04
# 2026-03-16 20:14:34 — src.models.train_nn — INFO — Epoch 007 | Loss: 0.5470 | AUC-ROC: 0.6709 | AUC-PR: 0.0615 | Brier: 0.0519 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 007 | Loss: 0.5470 | AUC-ROC: 0.6709 | AUC-PR: 0.0615 | Brier: 0.0519 | LR: 3.00e-04
# 2026-03-16 20:15:05 — src.models.train_nn — INFO — Epoch 008 | Loss: 0.5430 | AUC-ROC: 0.6761 | AUC-PR: 0.0641 | Brier: 0.0488 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 008 | Loss: 0.5430 | AUC-ROC: 0.6761 | AUC-PR: 0.0641 | Brier: 0.0488 | LR: 3.00e-04
# 2026-03-16 20:15:35 — src.models.train_nn — INFO — Epoch 009 | Loss: 0.5411 | AUC-ROC: 0.6710 | AUC-PR: 0.0619 | Brier: 0.0497 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 009 | Loss: 0.5411 | AUC-ROC: 0.6710 | AUC-PR: 0.0619 | Brier: 0.0497 | LR: 3.00e-04
# 2026-03-16 20:16:07 — src.models.train_nn — INFO — Epoch 010 | Loss: 0.5375 | AUC-ROC: 0.6662 | AUC-PR: 0.0629 | Brier: 0.0521 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 010 | Loss: 0.5375 | AUC-ROC: 0.6662 | AUC-PR: 0.0629 | Brier: 0.0521 | LR: 1.50e-04
# 2026-03-16 20:16:36 — src.models.train_nn — INFO — Epoch 011 | Loss: 0.5346 | AUC-ROC: 0.6643 | AUC-PR: 0.0627 | Brier: 0.0524 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 011 | Loss: 0.5346 | AUC-ROC: 0.6643 | AUC-PR: 0.0627 | Brier: 0.0524 | LR: 1.50e-04
# 2026-03-16 20:17:07 — src.models.train_nn — INFO — Epoch 012 | Loss: 0.5332 | AUC-ROC: 0.6840 | AUC-PR: 0.0656 | Brier: 0.0459 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 012 | Loss: 0.5332 | AUC-ROC: 0.6840 | AUC-PR: 0.0656 | Brier: 0.0459 | LR: 1.50e-04
# 2026-03-16 20:17:35 — src.models.train_nn — INFO — Epoch 013 | Loss: 0.5319 | AUC-ROC: 0.6727 | AUC-PR: 0.0651 | Brier: 0.0468 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 013 | Loss: 0.5319 | AUC-ROC: 0.6727 | AUC-PR: 0.0651 | Brier: 0.0468 | LR: 1.50e-04
# 2026-03-16 20:18:04 — src.models.train_nn — INFO — Epoch 014 | Loss: 0.5309 | AUC-ROC: 0.6802 | AUC-PR: 0.0658 | Brier: 0.0494 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 014 | Loss: 0.5309 | AUC-ROC: 0.6802 | AUC-PR: 0.0658 | Brier: 0.0494 | LR: 1.50e-04
# 2026-03-16 20:18:32 — src.models.train_nn — INFO — Epoch 015 | Loss: 0.5307 | AUC-ROC: 0.6910 | AUC-PR: 0.0673 | Brier: 0.0441 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 015 | Loss: 0.5307 | AUC-ROC: 0.6910 | AUC-PR: 0.0673 | Brier: 0.0441 | LR: 1.50e-04
# 2026-03-16 20:18:32 — src.models.train_nn — INFO — Early stopping at epoch 15 (best epoch: 3, best AUC: 0.6912)
# INFO:src.models.train_nn:Early stopping at epoch 15 (best epoch: 3, best AUC: 0.6912)
# c:\college\PROJECTS\ML\Loan-Risk-Intelligence\notebooks\..\src\models\train_nn.py:410: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(output_dir / "nn_best.pt", map_location=device)
# 2026/03/16 20:18:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/16 20:18:43 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# 2026/03/16 20:18:44 WARNING mlflow.utils.requirements_utils: Found torch version (2.5.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.5.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/03/16 20:18:55 WARNING mlflow.utils.requirements_utils: Found torch version (2.5.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.5.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026-03-16 20:18:55 — src.models.train_nn — INFO — NN training complete. Best AUC-ROC: 0.6912
# INFO:src.models.train_nn:NN training complete. Best AUC-ROC: 0.6912
