# %%
import pandas as pd

# %%
df=pd.read_stata('../data/raw/P2P_Macro_Data.dta')

# %%
df.to_parquet('../data/raw/P2P_Macro_Data.parquet', index=False)
print("Saved as parquet")
# Out:
# Saved as parquet

# %%
print("Shape:", df.shape)
print("\nbadloan distribution:")
print(df['badloan'].value_counts())
print(df['badloan'].value_counts(normalize=True).round(3))

print("\nMissing values (top 20):")
print(df.isnull().sum().sort_values(ascending=False).head(20))

print("\nDate range:")
print(df['issue_daily'].min(), "→", df['issue_daily'].max())
# Out:
# Shape: (2703430, 195)
#
# badloan distribution:
# badloan
# 0.0    2486808
# 1.0     216622
# Name: count, dtype: int64
# badloan
# 0.0    0.92
# 1.0    0.08
# Name: proportion, dtype: float64
#
# Missing values (top 20):
# url                               2703430
# verification_status_joint         2703430
# revol_bal_joint                   2526829
# sec_app_open_act_il               2526828
# dti_joint                         2514226
# annual_inc_joint                  2514222
# mths_since_last_record            2294084
# lognum_accts_ever_120_pd          2097855
# mths_since_recent_bc_dlq          2081980
# mths_since_last_major_derog       2010592
# mths_since_recent_revol_delinq    1819855
# mths_since_last_delinq            1402509
# open_act_il                       1229615
# il_util                           1067810
# logpercent_bc_gt_75                814961
# inq_last_12m                       795480
# open_acc_6m                        795480
# inq_fi                             795480
# total_cu_tl                        795480
# total_bal_il                       795480
# dtype: int64
#
# Date range:
# 2012-08-01 00:00:00 → 2019-12-01 00:00:00

# %%
df.columns.tolist()
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'total_bal_il',
#  'il_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'open_act_il',
#  'sec_app_open_act_il',
#  'issue_date',
#  'last_date',
#  'region',
#  'subregion',
#  'earnings',
#  'employment',
#  'labor_force',
#  'Muni',
#  'muni_m',
#  'FEDFUNDS',
#  'internetuser',
#  'internetuserprop',
#  'empl_exp_prop',
#  'empl_expan',
#  'empl_birth',
#  'empl_birth_per',
#  'new_bus',
#  'new_bus_per',
#  'popestimate',
#  'dem',
#  'rep',
#  'red',
#  'christianity',
#  'religiousity',
#  'unemployment',
#  'unem_rate',
#  'gdpindex',
#  'gdpreal',
#  'gdpcontrib',
#  'cpi',
#  'cpiregion',
#  'inf',
#  'gdppercap',
#  'des_length',
#  'application_type_',
#  'initial_list_status_',
#  'purpose_',
#  'pymnt_plan_',
#  'verification_status_',
#  'home_ownership_',
#  'emp_length_',
#  'grade_',
#  'sub_grade_',
#  'term_',
#  'loan_status_',
#  'badloan',
#  'rankloan_status_',
#  'logfunded_amnt',
#  'logannual_inc',
#  'logdti',
#  'logtotal_acc',
#  'logmo_sin_old_il_acct',
#  'logmo_sin_rcnt_tl',
#  'lognum_accts_ever_120_pd',
#  'logpct_tl_nvr_dlq',
#  'logpercent_bc_gt_75',
#  'logtot_hi_cred_lim',
#  'logearnings',
#  'logemployment',
#  'loglabor_force',
#  'logfinanceuser',
#  'logsocialnetworkuser',
#  'loginternetuser',
#  'logempl_expan',
#  'logempl_birth',
#  'lognew_bus',
#  'logpopestimate',
#  'logunemployment',
#  'loggdppercap',
#  'state',
#  'muni_points',
#  'muni_6m',
#  'inf_6m',
#  'loan_vol',
#  'loanmedian',
#  'median_dummy',
#  'daily_date',
#  'quarter',
#  'month',
#  'year',
#  'CPIUS',
#  'logCPIUS',
#  'infUS',
#  'logloan_vol',
#  'loan_status_5',
#  'meanopen_acc',
#  'FED_lag6',
#  'riskprem',
#  'loan_vol6m',
#  'loglvol_6m',
#  'issue_daily',
#  'issue_year',
#  'loan6m_median',
#  'loan_sum']

# %%
fico_check = [c for c in df.columns if 'fico' in c.lower()]
print("FICO columns:", fico_check)
# Out:
# FICO columns: []

# %%
# Check if baselinesample column exists
print('baselinesample' in df.columns)

# If it does:
if 'baselinesample' in df.columns:
    print(df['baselinesample'].value_counts())
    print("Baseline sample size:", df[df['baselinesample']==1].shape)
# Out:
# False

# %%
#SANITY CHECK
# Check 1: does baselinesample exist?
print("baselinesample exists:", 'baselinesample' in df.columns)

# Check 2: default rate by year
print("\nDefault rate by year:")
print(df.groupby('issue_year')['badloan'].mean().round(3))

# Check 3: default rate by grade
print("\nDefault rate by grade:")
print(df.groupby('grade_')['badloan'].mean().sort_values(ascending=False).round(3))

# Check 4: pymnt_plan variance (we discussed this might be near-zero)
print("\npymnt_plan distribution:")
print(df['pymnt_plan'].value_counts())
# Out:
# baselinesample exists: False
#
# Default rate by year:
# issue_year
# 2012.0    0.155
# 2013.0    0.150
# 2014.0    0.154
# 2015.0    0.185
# 2016.0    0.048
# 2017.0    0.077
# 2018.0    0.021
# 2019.0    0.025
# Name: badloan, dtype: float32
#
# Default rate by grade:
# grade_
# G    0.316
# F    0.287
# E    0.218
# D    0.131
# C    0.090
# B    0.052
# A    0.020
# Name: badloan, dtype: float32
#
# pymnt_plan distribution:
# pymnt_plan
# n    2703105
# y        325
# Name: count, dtype: int64
# C:\Users\Divyansh\AppData\Local\Temp\ipykernel_50728\879586789.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('grade_')['badloan'].mean().sort_values(ascending=False).round(3))

# %%
import sys
sys.path.append('..')  # so Python can find the src folder

from src.data.preprocess import run_preprocessing

df_clean = run_preprocessing()
# Out:
# 2026-03-09 16:55:25 — src.data.preprocess — INFO — ==================================================
# 2026-03-09 16:55:25 — src.data.preprocess — INFO — PREPROCESSING PIPELINE STARTED
# 2026-03-09 16:55:25 — src.data.preprocess — INFO — ==================================================
# 2026-03-09 16:55:25 — src.data.preprocess — INFO — Loading from parquet cache...
# 2026-03-09 16:55:32 — src.data.preprocess — INFO — Loaded raw data: (2703430, 195)
# 2026-03-09 16:55:34 — src.data.preprocess — INFO — Dropped 16 leakage columns: ['total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'out_prncp', 'out_prncp_inv', 'last_pymnt_amnt', 'last_pymnt_d', 'next_pymnt_d', 'loan_status', 'loan_status_', 'loan_status_5', 'rankloan_status_']
# 2026-03-09 16:55:37 — src.data.preprocess — INFO — Dropped 27 useless/redundant columns
# 2026-03-09 16:55:37 — src.data.preprocess — WARNING — Found 2 fully null columns: ['url', 'verification_status_joint']
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — Filtered 0 ambiguous rows — 2,703,430 remain
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — mths_since_last_delinq: filled 1,402,509 nulls with 999 (never delinquent)
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — mths_since_recent_bc: filled 28,608 nulls with 999 (never delinquent)
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — mths_since_recent_inq: filled 303,703 nulls with 999 (never delinquent)
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — il_util: filled 1,067,810 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — open_acc_6m: filled 795,480 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — inq_last_12m: filled 795,480 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — total_bal_il: filled 795,480 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — total_cu_tl: filled 795,480 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — inq_fi: filled 795,480 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — open_act_il: filled 1,229,615 nulls with 0
# 2026-03-09 16:55:38 — src.data.preprocess — INFO — num_tl_120dpd_2m: filled 90,484 nulls with 0
# 2026-03-09 16:55:39 — src.data.preprocess — INFO — revol_util: filled 2,161 nulls with median (0.4880)
# 2026-03-09 16:55:39 — src.data.preprocess — INFO — bc_open_to_buy: filled 30,409 nulls with median (6084.0000)
# 2026-03-09 16:55:39 — src.data.preprocess — INFO — bc_util: filled 31,782 nulls with median (57.9000)
# 2026-03-09 16:55:39 — src.data.preprocess — INFO — mo_sin_old_rev_tl_op: filled 1 nulls with median (162.0000)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — mo_sin_rcnt_rev_tl_op: filled 1 nulls with median (9.0000)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — num_rev_accts: filled 1 nulls with median (12.0000)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — Muni: filled 38,376 nulls with median (0.0255)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — logmo_sin_old_il_acct: filled 82,127 nulls with median (4.8675)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — logmo_sin_rcnt_tl: filled 42,765 nulls with median (1.7918)
# 2026-03-09 16:55:40 — src.data.preprocess — INFO — logsocialnetworkuser: filled 163 nulls with median (14.8115)
# 2026-03-09 16:55:43 — src.data.preprocess — INFO — All missing values resolved
# 2026-03-09 16:55:43 — src.data.preprocess — INFO — ==================================================
# 2026-03-09 16:55:43 — src.data.preprocess — INFO — PREPROCESSING COMPLETE — Final shape: (2703430, 152)
# 2026-03-09 16:55:44 — src.data.preprocess — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-09 16:55:44 — src.data.preprocess — INFO — ==================================================
# 2026-03-09 16:56:00 — src.data.preprocess — INFO — Saved processed data to C:\college\PROJECTS\ML\Loan-Risk-Intelligence\data\processed\features.parquet

# %%
import os

# Check if the current directory is 'notebooks'. If so, move up one level to the project root.
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

print("Current working directory:", os.getcwd())

import sys
sys.path.append('..')  # so Python can find the src folder
from src.data.preprocess import run_preprocessing
from src.features.build_features import build_features

# Load preprocessed data
df_clean = pd.read_parquet('data/processed/features.parquet')

# Build features
X, y = build_features(df_clean)

print(X.shape)
print(X.columns.tolist())
print(y.value_counts())
# Out:
# Current working directory: c:\college\PROJECTS\ML\Loan-Risk-Intelligence
# 2026-03-09 17:00:07 — src.features.build_features — INFO — ==================================================
# 2026-03-09 17:00:07 — src.features.build_features — INFO — FEATURE ENGINEERING STARTED
# 2026-03-09 17:00:07 — src.features.build_features — INFO — ==================================================
# 2026-03-09 17:00:07 — src.features.build_features — INFO — Step 1: Encoding categorical features
# 2026-03-09 17:00:07 — src.features.build_features — INFO — Label encoding grade_ — was category
# 2026-03-09 17:00:08 — src.features.build_features — INFO — Label encoding term_ — was category
# 2026-03-09 17:00:08 — src.features.build_features — INFO — Label encoding purpose_ — was category
# 2026-03-09 17:00:09 — src.features.build_features — INFO — Label encoding application_type_ — was category
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Label encoding initial_list_status_ — was category
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Step 2: Engineering interaction features
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Created: dti_x_unemployment (borrower × macro stress)
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Created: real_interest_rate (int_rate - inflation)
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Created: loan_to_income (affordability ratio)
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Created: util_x_delinq (utilization × delinquency)
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Created: fed_x_term (rate environment × loan duration)
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Step 3: Selecting final feature matrix
# 2026-03-09 17:00:10 — src.features.build_features — INFO — LOAN: 28/28 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — BORROWER: 5/5 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — MACRO: 16/16 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — CATEGORICAL: 5/5 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — TIME: 3/3 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — INTERACTION: 5/5 features present
# 2026-03-09 17:00:10 — src.features.build_features — INFO — Final feature count: 62
# 2026-03-09 17:00:11 — src.features.build_features — INFO — Feature matrix shape: (2703430, 62)
# 2026-03-09 17:00:11 — src.features.build_features — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-09 17:00:11 — src.features.build_features — INFO — FEATURE ENGINEERING COMPLETE
# (2703430, 62)
# ['logfunded_amnt', 'int_rate', 'installment', 'inq_last_6mths', 'open_acc', 'logtotal_acc', 'pub_rec', 'des_length', 'logpct_tl_nvr_dlq', 'logtot_hi_cred_lim', 'revol_util', 'revol_bal', 'delinq_2yrs', 'mths_since_last_delinq', 'mths_since_recent_inq', 'mths_since_recent_bc', 'acc_open_past_24mths', 'mort_acc', 'pub_rec_bankruptcies', 'tax_liens', 'acc_now_delinq', 'num_tl_90g_dpd_24m', 'pct_tl_nvr_dlq', 'tot_cur_bal', 'avg_cur_bal', 'bc_util', 'num_actv_bc_tl', 'num_actv_rev_tl', 'logannual_inc', 'logdti', 'emp_length_', 'home_ownership_', 'verification_status_', 'logearnings', 'logunemployment', 'loglabor_force', 'logempl_birth', 'lognew_bus', 'gdpcontrib', 'loginternetuser', 'inf', 'inf_6m', 'muni_points', 'muni_6m', 'FEDFUNDS', 'FED_lag6', 'riskprem', 'CPIUS', 'cpi', 'grade_', 'term_', 'purpose_', 'application_type_', 'initial_list_status_', 'issue_year', 'quarter', 'month', 'dti_x_unemployment', 'real_interest_rate', 'loan_to_income', 'util_x_delinq', 'fed_x_term']
# badloan
# 0.0    2486808
# 1.0     216622
# Name: count, dtype: int64

# %%
from src.models.train_xgboost import run_xgboost_training

model = run_xgboost_training()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from src.models.train_xgboost import run_xgboost_training
# ----> 3 model = run_xgboost_training()
#
# File c:\college\PROJECTS\ML\Loan-Risk-Intelligence\notebooks\..\src\models\train_xgboost.py:248, in run_xgboost_training(config_path)
#     245 """Entry point — loads data, builds features, trains model."""
#     246 from src.features.build_features import build_features
# --> 248 config = load_config(config_path)
#     250 logger.info("Loading processed data...")
#     251 df = pd.read_parquet(config["paths"]["processed_data"])
#
# File c:\college\PROJECTS\ML\Loan-Risk-Intelligence\notebooks\..\src\models\train_xgboost.py:20, in load_config(config_path)
#      19 def load_config(config_path: str = "configs/config.yaml") -> dict:
# ---> 20     with open(config_path, "r") as f:
#      21         return yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'configs/config.yaml'
