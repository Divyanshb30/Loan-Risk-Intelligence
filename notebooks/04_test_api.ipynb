# %%
import requests

test_payload = {
    "features": {
        "int_rate": 0.15,
        "logdti": 2.1,
        "logannual_inc": 10.5,
        "grade_": 3,
        "FEDFUNDS_resid": 0.8,
        "CPIUS_resid": 0.5,
        "issue_year": 2017,
        "revol_util": 65.0,
        "revol_bal": 15000.0,
        "term_": 1
    }
}

response = requests.post("http://127.0.0.1:8000/predict", json=test_payload)
print(response.json())
# Out:
# {'default_probability': 0.605, 'risk_tier': 'High', 'top_shap_drivers': [{'feature': 'logtotal_acc', 'shap_value': 0.375, 'direction': 'increases_risk'}, {'feature': 'purpose_', 'shap_value': -0.3191, 'direction': 'reduces_risk'}, {'feature': 'loan_to_income', 'shap_value': -0.2935, 'direction': 'reduces_risk'}]}
