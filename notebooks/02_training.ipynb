# %%
import sys, os

# Make sure the project root is on the Python path
sys.path.insert(0, os.path.abspath('..'))

# Confirm it worked
print(sys.path[0])  # should print the project root

import importlib
import src.features.build_features as bf
import src.models.train_xgboost as txgb
import src.models.train_nn as tnn
import src.data.preprocess as pre

importlib.reload(bf)
importlib.reload(txgb)
importlib.reload(tnn)
importlib.reload(pre)
print("All modules reloaded.")
# Out:
# c:\college\PROJECTS\ML\Loan-Risk-Intelligence
# All modules reloaded.

# %%
import sys, os

# ── Fix 1: make `src` importable ──────────────────────────────────────────────
project_root = os.path.abspath('..')
sys.path.insert(0, project_root)

# ── Fix 2: move CWD to project root so relative paths in config.yaml work ────
os.chdir(project_root)

print("CWD:", os.getcwd())       # should be: .../Loan-Risk-Intelligence
print("sys.path[0]:", sys.path[0])

from src.models.train_xgboost import run_xgboost_training
model = run_xgboost_training()
# Out:
# CWD: c:\college\PROJECTS\ML\Loan-Risk-Intelligence
# sys.path[0]: c:\college\PROJECTS\ML\Loan-Risk-Intelligence
# 2026-03-21 17:01:47 — src.models.train_xgboost — INFO — Loading processed data...
# INFO:src.models.train_xgboost:Loading processed data...
# 2026-03-21 17:01:49 — src.features.build_features — INFO — ==================================================
# INFO:src.features.build_features:==================================================
# 2026-03-21 17:01:49 — src.features.build_features — INFO — FEATURE ENGINEERING STARTED
# INFO:src.features.build_features:FEATURE ENGINEERING STARTED
# 2026-03-21 17:01:49 — src.features.build_features — INFO — ==================================================
# INFO:src.features.build_features:==================================================
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Step 1: Encoding categorical + borrower categorical features
# INFO:src.features.build_features:Step 1: Encoding categorical + borrower categorical features
# 2026-03-21 17:01:49 — src.features.build_features — INFO — grade_: category -> int codes (7 unique values)
# INFO:src.features.build_features:grade_: category -> int codes (7 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — term_: category -> int codes (2 unique values)
# INFO:src.features.build_features:term_: category -> int codes (2 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — purpose_: category -> int codes (13 unique values)
# INFO:src.features.build_features:purpose_: category -> int codes (13 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — application_type_: category -> int codes (5 unique values)
# INFO:src.features.build_features:application_type_: category -> int codes (5 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — initial_list_status_: category -> int codes (2 unique values)
# INFO:src.features.build_features:initial_list_status_: category -> int codes (2 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — emp_length_: category -> int codes (12 unique values)
# INFO:src.features.build_features:emp_length_: category -> int codes (12 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — home_ownership_: category -> int codes (6 unique values)
# INFO:src.features.build_features:home_ownership_: category -> int codes (6 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — verification_status_: category -> int codes (3 unique values)
# INFO:src.features.build_features:verification_status_: category -> int codes (3 unique values)
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Step 2: Residualizing macro features against time
# INFO:src.features.build_features:Step 2: Residualizing macro features against time
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: muni_6m -> muni_6m_resid
# INFO:src.features.build_features:Residualized: muni_6m -> muni_6m_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: FED_lag6 -> FED_lag6_resid
# INFO:src.features.build_features:Residualized: FED_lag6 -> FED_lag6_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: CPIUS -> CPIUS_resid
# INFO:src.features.build_features:Residualized: CPIUS -> CPIUS_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: FEDFUNDS -> FEDFUNDS_resid
# INFO:src.features.build_features:Residualized: FEDFUNDS -> FEDFUNDS_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: inf -> inf_resid
# INFO:src.features.build_features:Residualized: inf -> inf_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: inf_6m -> inf_6m_resid
# INFO:src.features.build_features:Residualized: inf_6m -> inf_6m_resid
# 2026-03-21 17:01:49 — src.features.build_features — INFO — Residualized: muni_points -> muni_points_resid
# INFO:src.features.build_features:Residualized: muni_points -> muni_points_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Residualized: riskprem -> riskprem_resid
# INFO:src.features.build_features:Residualized: riskprem -> riskprem_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Residualized: cpi -> cpi_resid
# INFO:src.features.build_features:Residualized: cpi -> cpi_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Residualized: logunemployment -> logunemployment_resid
# INFO:src.features.build_features:Residualized: logunemployment -> logunemployment_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Residualized: logearnings -> logearnings_resid
# INFO:src.features.build_features:Residualized: logearnings -> logearnings_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Residualized: gdpcontrib -> gdpcontrib_resid
# INFO:src.features.build_features:Residualized: gdpcontrib -> gdpcontrib_resid
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Step 3: Engineering interaction features
# INFO:src.features.build_features:Step 3: Engineering interaction features
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Created: dti_x_unemployment (using logunemployment_resid)
# INFO:src.features.build_features:Created: dti_x_unemployment (using logunemployment_resid)
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Created: real_interest_rate
# INFO:src.features.build_features:Created: real_interest_rate
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Created: loan_to_income
# INFO:src.features.build_features:Created: loan_to_income
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Created: util_x_delinq
# INFO:src.features.build_features:Created: util_x_delinq
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Created: fed_x_term
# INFO:src.features.build_features:Created: fed_x_term
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Step 4: Selecting final feature matrix
# INFO:src.features.build_features:Step 4: Selecting final feature matrix
# 2026-03-21 17:01:50 — src.features.build_features — INFO — LOAN: 28/28 features present
# INFO:src.features.build_features:LOAN: 28/28 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — BORROWER: 5/5 features present
# INFO:src.features.build_features:BORROWER: 5/5 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — MACRO: 16/16 features present
# INFO:src.features.build_features:MACRO: 16/16 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — CATEGORICAL: 5/5 features present
# INFO:src.features.build_features:CATEGORICAL: 5/5 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — TIME: 1/1 features present
# INFO:src.features.build_features:TIME: 1/1 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — INTERACTION: 5/5 features present
# INFO:src.features.build_features:INTERACTION: 5/5 features present
# 2026-03-21 17:01:50 — src.features.build_features — INFO — Final feature count: 60
# INFO:src.features.build_features:Final feature count: 60
# 2026-03-21 17:01:51 — src.features.build_features — INFO — Step 5: Enforcing numeric dtypes
# INFO:src.features.build_features:Step 5: Enforcing numeric dtypes
# 2026-03-21 17:01:51 — src.features.build_features — INFO — All 60 features verified numeric — safe for XGBoost/PyTorch
# INFO:src.features.build_features:All 60 features verified numeric — safe for XGBoost/PyTorch
# 2026-03-21 17:01:51 — src.features.build_features — INFO — Feature matrix shape: (2703430, 60)
# INFO:src.features.build_features:Feature matrix shape: (2703430, 60)
# 2026-03-21 17:01:51 — src.features.build_features — INFO — Target distribution: {0.0: 0.92, 1.0: 0.08}
# INFO:src.features.build_features:Target distribution: {0.0: 0.92, 1.0: 0.08}
# 2026-03-21 17:01:51 — src.features.build_features — INFO — FEATURE ENGINEERING COMPLETE
# INFO:src.features.build_features:FEATURE ENGINEERING COMPLETE
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — Split mode: year_stratified
# INFO:src.models.train_xgboost:Split mode: year_stratified
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — Train: 2,162,744 | Test: 540,686
# INFO:src.models.train_xgboost:Train: 2,162,744 | Test: 540,686
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — Train default rate: 0.080 | Test default rate:  0.080
# INFO:src.models.train_xgboost:Train default rate: 0.080 | Test default rate:  0.080
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — Class distribution — Negative: 1,989,390 | Positive: 173,354
# INFO:src.models.train_xgboost:Class distribution — Negative: 1,989,390 | Positive: 173,354
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — scale_pos_weight set to: 11.4759
# INFO:src.models.train_xgboost:scale_pos_weight set to: 11.4759
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — Generating OOF predictions for NN stacking...
# INFO:src.models.train_xgboost:Generating OOF predictions for NN stacking...
# 2026-03-21 17:01:57 — src.models.train_xgboost — INFO — OOF fold 1/5...
# INFO:src.models.train_xgboost:OOF fold 1/5...
# 2026-03-21 17:02:02 — src.models.train_xgboost — INFO —   Fold 1 OOF AUC: 0.9147
# INFO:src.models.train_xgboost:  Fold 1 OOF AUC: 0.9147
# 2026-03-21 17:02:02 — src.models.train_xgboost — INFO — OOF fold 2/5...
# INFO:src.models.train_xgboost:OOF fold 2/5...
# 2026-03-21 17:02:08 — src.models.train_xgboost — INFO —   Fold 2 OOF AUC: 0.9164
# INFO:src.models.train_xgboost:  Fold 2 OOF AUC: 0.9164
# 2026-03-21 17:02:08 — src.models.train_xgboost — INFO — OOF fold 3/5...
# INFO:src.models.train_xgboost:OOF fold 3/5...
# 2026-03-21 17:02:14 — src.models.train_xgboost — INFO —   Fold 3 OOF AUC: 0.9177
# INFO:src.models.train_xgboost:  Fold 3 OOF AUC: 0.9177
# 2026-03-21 17:02:14 — src.models.train_xgboost — INFO — OOF fold 4/5...
# INFO:src.models.train_xgboost:OOF fold 4/5...
# 2026-03-21 17:02:22 — src.models.train_xgboost — INFO —   Fold 4 OOF AUC: 0.9174
# INFO:src.models.train_xgboost:  Fold 4 OOF AUC: 0.9174
# 2026-03-21 17:02:22 — src.models.train_xgboost — INFO — OOF fold 5/5...
# INFO:src.models.train_xgboost:OOF fold 5/5...
# 2026-03-21 17:02:32 — src.models.train_xgboost — INFO —   Fold 5 OOF AUC: 0.9181
# INFO:src.models.train_xgboost:  Fold 5 OOF AUC: 0.9181
# 2026-03-21 17:02:32 — src.models.train_xgboost — INFO — Samples with OOF predictions: 1,802,285 / 2,162,744 (360,459 excluded — first TimeSeriesSplit chunk)
# INFO:src.models.train_xgboost:Samples with OOF predictions: 1,802,285 / 2,162,744 (360,459 excluded — first TimeSeriesSplit chunk)
# 2026-03-21 17:02:33 — src.models.train_xgboost — INFO — Valid OOF AUC: 0.9168
# INFO:src.models.train_xgboost:Valid OOF AUC: 0.9168
# 2026-03-21 17:02:33 — src.models.train_xgboost — INFO — Class distribution — Negative: 1,989,390 | Positive: 173,354
# INFO:src.models.train_xgboost:Class distribution — Negative: 1,989,390 | Positive: 173,354
# 2026-03-21 17:02:33 — src.models.train_xgboost — INFO — scale_pos_weight set to: 11.4759
# INFO:src.models.train_xgboost:scale_pos_weight set to: 11.4759
# 2026-03-21 17:02:34 — src.models.train_xgboost — INFO — Running TimeSeriesSplit cross-validation...
# INFO:src.models.train_xgboost:Running TimeSeriesSplit cross-validation...
# 2026-03-21 17:02:40 — src.models.train_xgboost — INFO — Fold 1 — AUC-ROC: 0.9148 | AUC-PR: 0.4441 | Brier: 0.1187
# INFO:src.models.train_xgboost:Fold 1 — AUC-ROC: 0.9148 | AUC-PR: 0.4441 | Brier: 0.1187
# 2026-03-21 17:02:46 — src.models.train_xgboost — INFO — Fold 2 — AUC-ROC: 0.9164 | AUC-PR: 0.4582 | Brier: 0.1211
# INFO:src.models.train_xgboost:Fold 2 — AUC-ROC: 0.9164 | AUC-PR: 0.4582 | Brier: 0.1211
# 2026-03-21 17:02:54 — src.models.train_xgboost — INFO — Fold 3 — AUC-ROC: 0.9177 | AUC-PR: 0.4595 | Brier: 0.1227
# INFO:src.models.train_xgboost:Fold 3 — AUC-ROC: 0.9177 | AUC-PR: 0.4595 | Brier: 0.1227
# 2026-03-21 17:03:04 — src.models.train_xgboost — INFO — Fold 4 — AUC-ROC: 0.9174 | AUC-PR: 0.4569 | Brier: 0.1238
# INFO:src.models.train_xgboost:Fold 4 — AUC-ROC: 0.9174 | AUC-PR: 0.4569 | Brier: 0.1238
# 2026-03-21 17:03:16 — src.models.train_xgboost — INFO — Fold 5 — AUC-ROC: 0.9181 | AUC-PR: 0.4606 | Brier: 0.1243
# INFO:src.models.train_xgboost:Fold 5 — AUC-ROC: 0.9181 | AUC-PR: 0.4606 | Brier: 0.1243
# 2026-03-21 17:03:16 — src.models.train_xgboost — INFO —
# CV Summary — AUC-ROC: 0.9169 ± 0.0012 | AUC-PR: 0.4558 ± 0.0060 | Brier: 0.1221 ± 0.0020
# INFO:src.models.train_xgboost:
# CV Summary — AUC-ROC: 0.9169 ± 0.0012 | AUC-PR: 0.4558 ± 0.0060 | Brier: 0.1221 ± 0.0020
# 2026-03-21 17:03:16 — src.models.train_xgboost — INFO — Training final model on full training set...
# INFO:src.models.train_xgboost:Training final model on full training set...
# [0]	validation_0-auc:0.88904
# [100]	validation_0-auc:0.91094
# [200]	validation_0-auc:0.91446
# [300]	validation_0-auc:0.91602
# [400]	validation_0-auc:0.91701
# [499]	validation_0-auc:0.91759
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO —
# ========================================
# INFO:src.models.train_xgboost:
# ========================================
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO — EVALUATION — TEST
# INFO:src.models.train_xgboost:EVALUATION — TEST
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO — AUC-ROC:     0.9176
# INFO:src.models.train_xgboost:AUC-ROC:     0.9176
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO — AUC-PR:      0.4599
# INFO:src.models.train_xgboost:AUC-PR:      0.4599
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO — Brier Score: 0.1250
# INFO:src.models.train_xgboost:Brier Score: 0.1250
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO —
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9907    0.7983    0.8842    497418
#          1.0     0.2828    0.9140    0.4319     43268
#
#     accuracy                         0.8076    540686
#    macro avg     0.6367    0.8562    0.6580    540686
# weighted avg     0.9341    0.8076    0.8480    540686
# INFO:src.models.train_xgboost:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9907    0.7983    0.8842    497418
#          1.0     0.2828    0.9140    0.4319     43268
#
#     accuracy                         0.8076    540686
#    macro avg     0.6367    0.8562    0.6580    540686
# weighted avg     0.9341    0.8076    0.8480    540686
# 2026-03-21 17:03:29 — src.models.train_xgboost — INFO —
# Top 10 features:
#               feature  importance
# 36     FEDFUNDS_resid    0.303973
# 35        CPIUS_resid    0.137705
# 49             grade_    0.111794
# 54         issue_year    0.041212
# 40     riskprem_resid    0.035799
# 33      muni_6m_resid    0.032231
# 37          inf_resid    0.030223
# 50              term_    0.028140
# 34     FED_lag6_resid    0.023400
# 39  muni_points_resid    0.023366
# INFO:src.models.train_xgboost:
# Top 10 features:
#               feature  importance
# 36     FEDFUNDS_resid    0.303973
# 35        CPIUS_resid    0.137705
# 49             grade_    0.111794
# 54         issue_year    0.041212
# 40     riskprem_resid    0.035799
# 33      muni_6m_resid    0.032231
# 37          inf_resid    0.030223
# 50              term_    0.028140
# 34     FED_lag6_resid    0.023400
# 39  muni_points_resid    0.023366
# 2026/03/21 17:03:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026-03-21 17:03:42 — src.models.train_xgboost — INFO — Model saved to C:\college\PROJECTS\ML\Loan-Risk-Intelligence\data\outputs\xgb_model.json
# INFO:src.models.train_xgboost:Model saved to C:\college\PROJECTS\ML\Loan-Risk-Intelligence\data\outputs\xgb_model.json
# 2026-03-21 17:03:42 — src.models.train_xgboost — INFO — MLflow run ID: 9862f99b5a204ba7a965134464b9a627
# INFO:src.models.train_xgboost:MLflow run ID: 9862f99b5a204ba7a965134464b9a627
# 2026-03-21 17:03:48 — src.models.train_xgboost — INFO — All outputs saved. XGBoost training complete.
# INFO:src.models.train_xgboost:All outputs saved. XGBoost training complete.

# %%
import numpy as np
from sklearn.metrics import roc_auc_score
import pandas as pd

oof = np.load("data/outputs/xgb_oof_predictions.npy")
mask = np.load("data/outputs/xgb_oof_valid_mask.npy")
y_train = pd.read_parquet("data/outputs/y_train.parquet").values.ravel()

print(f"Total train rows  : {len(oof):,}")
print(f"Valid OOF rows    : {mask.sum():,}")
print(f"Excluded (NaN)    : {(~mask).sum():,}  ← first TSS chunk, expected")
print(f"Valid OOF AUC     : {roc_auc_score(y_train[mask], oof[mask]):.4f}")  # expect > 0.84
# Out:
# Total train rows  : 2,162,744
# Valid OOF rows    : 1,802,285
# Excluded (NaN)    : 360,459  ← first TSS chunk, expected
# Valid OOF AUC     : 0.9168

# %%
from src.models.train_nn import run_nn_training
model_nn, nn_probs = run_nn_training()
# Out:
# 2026-03-21 17:04:26 — src.models.train_nn — INFO — GPU: NVIDIA GeForce RTX 3060 Laptop GPU | VRAM: 6.0GB
# INFO:src.models.train_nn:GPU: NVIDIA GeForce RTX 3060 Laptop GPU | VRAM: 6.0GB
# 2026-03-21 17:04:26 — src.models.train_nn — INFO — Loading train/test splits...
# INFO:src.models.train_nn:Loading train/test splits...
# 2026-03-21 17:04:27 — src.models.train_nn — INFO — Train size after mask: 1,802,285
# INFO:src.models.train_nn:Train size after mask: 1,802,285
# 2026-03-21 17:04:27 — src.models.train_nn — INFO — Scaling features...
# INFO:src.models.train_nn:Scaling features...
# 2026-03-21 17:04:29 — src.models.train_nn — INFO — Final input dim: 61 (62 features + 1 XGB logit)
# INFO:src.models.train_nn:Final input dim: 61 (62 features + 1 XGB logit)
# 2026-03-21 17:04:29 — src.models.train_nn — INFO — NaN check passed — clean inputs confirmed
# INFO:src.models.train_nn:NaN check passed — clean inputs confirmed
# 2026-03-21 17:04:29 — src.models.train_nn — INFO — Loss: BCE | pos_weight=3.00 (raw=11.5, cap=3.0)
# INFO:src.models.train_nn:Loss: BCE | pos_weight=3.00 (raw=11.5, cap=3.0)
# 2026-03-21 17:05:24 — src.models.train_nn — INFO — Epoch 001 | Loss: 0.4927 | Train AUC: 0.9108 | Test AUC: 0.9104 | AUC-PR: 0.3939 | Brier: 0.0872 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 001 | Loss: 0.4927 | Train AUC: 0.9108 | Test AUC: 0.9104 | AUC-PR: 0.3939 | Brier: 0.0872 | LR: 3.00e-04
# 2026-03-21 17:05:24 — src.models.train_nn — INFO —   -> New best AUC: 0.9104 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9104 (saved)
# 2026-03-21 17:06:16 — src.models.train_nn — INFO — Epoch 002 | Loss: 0.3565 | Train AUC: 0.9155 | Test AUC: 0.9147 | AUC-PR: 0.4299 | Brier: 0.0750 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 002 | Loss: 0.3565 | Train AUC: 0.9155 | Test AUC: 0.9147 | AUC-PR: 0.4299 | Brier: 0.0750 | LR: 3.00e-04
# 2026-03-21 17:06:16 — src.models.train_nn — INFO —   -> New best AUC: 0.9147 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9147 (saved)
# 2026-03-21 17:07:06 — src.models.train_nn — INFO — Epoch 003 | Loss: 0.3452 | Train AUC: 0.9168 | Test AUC: 0.9160 | AUC-PR: 0.4435 | Brier: 0.0724 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 003 | Loss: 0.3452 | Train AUC: 0.9168 | Test AUC: 0.9160 | AUC-PR: 0.4435 | Brier: 0.0724 | LR: 3.00e-04
# 2026-03-21 17:07:06 — src.models.train_nn — INFO —   -> New best AUC: 0.9160 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9160 (saved)
# 2026-03-21 17:08:00 — src.models.train_nn — INFO — Epoch 004 | Loss: 0.3410 | Train AUC: 0.9174 | Test AUC: 0.9164 | AUC-PR: 0.4479 | Brier: 0.0693 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 004 | Loss: 0.3410 | Train AUC: 0.9174 | Test AUC: 0.9164 | AUC-PR: 0.4479 | Brier: 0.0693 | LR: 3.00e-04
# 2026-03-21 17:08:00 — src.models.train_nn — INFO —   -> New best AUC: 0.9164 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9164 (saved)
# 2026-03-21 17:08:55 — src.models.train_nn — INFO — Epoch 005 | Loss: 0.3385 | Train AUC: 0.9177 | Test AUC: 0.9167 | AUC-PR: 0.4518 | Brier: 0.0706 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 005 | Loss: 0.3385 | Train AUC: 0.9177 | Test AUC: 0.9167 | AUC-PR: 0.4518 | Brier: 0.0706 | LR: 3.00e-04
# 2026-03-21 17:08:55 — src.models.train_nn — INFO —   -> New best AUC: 0.9167 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9167 (saved)
# 2026-03-21 17:09:50 — src.models.train_nn — INFO — Epoch 006 | Loss: 0.3370 | Train AUC: 0.9181 | Test AUC: 0.9170 | AUC-PR: 0.4531 | Brier: 0.0678 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 006 | Loss: 0.3370 | Train AUC: 0.9181 | Test AUC: 0.9170 | AUC-PR: 0.4531 | Brier: 0.0678 | LR: 3.00e-04
# 2026-03-21 17:09:50 — src.models.train_nn — INFO —   -> New best AUC: 0.9170 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9170 (saved)
# 2026-03-21 17:10:42 — src.models.train_nn — INFO — Epoch 007 | Loss: 0.3350 | Train AUC: 0.9183 | Test AUC: 0.9172 | AUC-PR: 0.4546 | Brier: 0.0680 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 007 | Loss: 0.3350 | Train AUC: 0.9183 | Test AUC: 0.9172 | AUC-PR: 0.4546 | Brier: 0.0680 | LR: 3.00e-04
# 2026-03-21 17:10:42 — src.models.train_nn — INFO —   -> New best AUC: 0.9172 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9172 (saved)
# 2026-03-21 17:11:33 — src.models.train_nn — INFO — Epoch 008 | Loss: 0.3340 | Train AUC: 0.9185 | Test AUC: 0.9174 | AUC-PR: 0.4563 | Brier: 0.0679 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 008 | Loss: 0.3340 | Train AUC: 0.9185 | Test AUC: 0.9174 | AUC-PR: 0.4563 | Brier: 0.0679 | LR: 3.00e-04
# 2026-03-21 17:11:33 — src.models.train_nn — INFO —   -> New best AUC: 0.9174 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9174 (saved)
# 2026-03-21 17:12:25 — src.models.train_nn — INFO — Epoch 009 | Loss: 0.3336 | Train AUC: 0.9187 | Test AUC: 0.9175 | AUC-PR: 0.4568 | Brier: 0.0674 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 009 | Loss: 0.3336 | Train AUC: 0.9187 | Test AUC: 0.9175 | AUC-PR: 0.4568 | Brier: 0.0674 | LR: 3.00e-04
# 2026-03-21 17:12:25 — src.models.train_nn — INFO —   -> New best AUC: 0.9175 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9175 (saved)
# 2026-03-21 17:13:14 — src.models.train_nn — INFO — Epoch 010 | Loss: 0.3329 | Train AUC: 0.9187 | Test AUC: 0.9175 | AUC-PR: 0.4571 | Brier: 0.0663 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 010 | Loss: 0.3329 | Train AUC: 0.9187 | Test AUC: 0.9175 | AUC-PR: 0.4571 | Brier: 0.0663 | LR: 3.00e-04
# 2026-03-21 17:13:14 — src.models.train_nn — INFO —   -> New best AUC: 0.9175 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9175 (saved)
# 2026-03-21 17:14:10 — src.models.train_nn — INFO — Epoch 011 | Loss: 0.3324 | Train AUC: 0.9190 | Test AUC: 0.9177 | AUC-PR: 0.4589 | Brier: 0.0663 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 011 | Loss: 0.3324 | Train AUC: 0.9190 | Test AUC: 0.9177 | AUC-PR: 0.4589 | Brier: 0.0663 | LR: 3.00e-04
# 2026-03-21 17:14:10 — src.models.train_nn — INFO —   -> New best AUC: 0.9177 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9177 (saved)
# 2026-03-21 17:15:02 — src.models.train_nn — INFO — Epoch 012 | Loss: 0.3326 | Train AUC: 0.9190 | Test AUC: 0.9178 | AUC-PR: 0.4588 | Brier: 0.0659 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 012 | Loss: 0.3326 | Train AUC: 0.9190 | Test AUC: 0.9178 | AUC-PR: 0.4588 | Brier: 0.0659 | LR: 3.00e-04
# 2026-03-21 17:15:02 — src.models.train_nn — INFO —   -> New best AUC: 0.9178 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9178 (saved)
# 2026-03-21 17:15:56 — src.models.train_nn — INFO — Epoch 013 | Loss: 0.3315 | Train AUC: 0.9191 | Test AUC: 0.9179 | AUC-PR: 0.4594 | Brier: 0.0660 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 013 | Loss: 0.3315 | Train AUC: 0.9191 | Test AUC: 0.9179 | AUC-PR: 0.4594 | Brier: 0.0660 | LR: 3.00e-04
# 2026-03-21 17:15:56 — src.models.train_nn — INFO —   -> New best AUC: 0.9179 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9179 (saved)
# 2026-03-21 17:16:44 — src.models.train_nn — INFO — Epoch 014 | Loss: 0.3308 | Train AUC: 0.9193 | Test AUC: 0.9179 | AUC-PR: 0.4599 | Brier: 0.0673 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 014 | Loss: 0.3308 | Train AUC: 0.9193 | Test AUC: 0.9179 | AUC-PR: 0.4599 | Brier: 0.0673 | LR: 3.00e-04
# 2026-03-21 17:16:45 — src.models.train_nn — INFO —   -> New best AUC: 0.9179 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9179 (saved)
# 2026-03-21 17:17:40 — src.models.train_nn — INFO — Epoch 015 | Loss: 0.3306 | Train AUC: 0.9194 | Test AUC: 0.9180 | AUC-PR: 0.4606 | Brier: 0.0666 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 015 | Loss: 0.3306 | Train AUC: 0.9194 | Test AUC: 0.9180 | AUC-PR: 0.4606 | Brier: 0.0666 | LR: 3.00e-04
# 2026-03-21 17:17:40 — src.models.train_nn — INFO —   -> New best AUC: 0.9180 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9180 (saved)
# 2026-03-21 17:18:37 — src.models.train_nn — INFO — Epoch 016 | Loss: 0.3304 | Train AUC: 0.9195 | Test AUC: 0.9180 | AUC-PR: 0.4608 | Brier: 0.0658 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 016 | Loss: 0.3304 | Train AUC: 0.9195 | Test AUC: 0.9180 | AUC-PR: 0.4608 | Brier: 0.0658 | LR: 3.00e-04
# 2026-03-21 17:18:37 — src.models.train_nn — INFO —   -> New best AUC: 0.9180 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9180 (saved)
# 2026-03-21 17:19:30 — src.models.train_nn — INFO — Epoch 017 | Loss: 0.3305 | Train AUC: 0.9196 | Test AUC: 0.9181 | AUC-PR: 0.4613 | Brier: 0.0661 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 017 | Loss: 0.3305 | Train AUC: 0.9196 | Test AUC: 0.9181 | AUC-PR: 0.4613 | Brier: 0.0661 | LR: 3.00e-04
# 2026-03-21 17:19:30 — src.models.train_nn — INFO —   -> New best AUC: 0.9181 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9181 (saved)
# 2026-03-21 17:20:20 — src.models.train_nn — INFO — Epoch 018 | Loss: 0.3300 | Train AUC: 0.9197 | Test AUC: 0.9181 | AUC-PR: 0.4614 | Brier: 0.0671 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 018 | Loss: 0.3300 | Train AUC: 0.9197 | Test AUC: 0.9181 | AUC-PR: 0.4614 | Brier: 0.0671 | LR: 3.00e-04
# 2026-03-21 17:21:08 — src.models.train_nn — INFO — Epoch 019 | Loss: 0.3297 | Train AUC: 0.9199 | Test AUC: 0.9181 | AUC-PR: 0.4618 | Brier: 0.0661 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 019 | Loss: 0.3297 | Train AUC: 0.9199 | Test AUC: 0.9181 | AUC-PR: 0.4618 | Brier: 0.0661 | LR: 3.00e-04
# 2026-03-21 17:21:08 — src.models.train_nn — INFO —   -> New best AUC: 0.9181 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9181 (saved)
# 2026-03-21 17:22:03 — src.models.train_nn — INFO — Epoch 020 | Loss: 0.3293 | Train AUC: 0.9199 | Test AUC: 0.9182 | AUC-PR: 0.4623 | Brier: 0.0679 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 020 | Loss: 0.3293 | Train AUC: 0.9199 | Test AUC: 0.9182 | AUC-PR: 0.4623 | Brier: 0.0679 | LR: 3.00e-04
# 2026-03-21 17:22:03 — src.models.train_nn — INFO —   -> New best AUC: 0.9182 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9182 (saved)
# 2026-03-21 17:22:58 — src.models.train_nn — INFO — Epoch 021 | Loss: 0.3292 | Train AUC: 0.9202 | Test AUC: 0.9182 | AUC-PR: 0.4628 | Brier: 0.0651 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 021 | Loss: 0.3292 | Train AUC: 0.9202 | Test AUC: 0.9182 | AUC-PR: 0.4628 | Brier: 0.0651 | LR: 3.00e-04
# 2026-03-21 17:22:58 — src.models.train_nn — INFO —   -> New best AUC: 0.9182 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9182 (saved)
# 2026-03-21 17:23:53 — src.models.train_nn — INFO — Epoch 022 | Loss: 0.3297 | Train AUC: 0.9202 | Test AUC: 0.9181 | AUC-PR: 0.4621 | Brier: 0.0646 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 022 | Loss: 0.3297 | Train AUC: 0.9202 | Test AUC: 0.9181 | AUC-PR: 0.4621 | Brier: 0.0646 | LR: 3.00e-04
# 2026-03-21 17:24:48 — src.models.train_nn — INFO — Epoch 023 | Loss: 0.3296 | Train AUC: 0.9203 | Test AUC: 0.9182 | AUC-PR: 0.4631 | Brier: 0.0654 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 023 | Loss: 0.3296 | Train AUC: 0.9203 | Test AUC: 0.9182 | AUC-PR: 0.4631 | Brier: 0.0654 | LR: 3.00e-04
# 2026-03-21 17:25:41 — src.models.train_nn — INFO — Epoch 024 | Loss: 0.3286 | Train AUC: 0.9204 | Test AUC: 0.9182 | AUC-PR: 0.4627 | Brier: 0.0645 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 024 | Loss: 0.3286 | Train AUC: 0.9204 | Test AUC: 0.9182 | AUC-PR: 0.4627 | Brier: 0.0645 | LR: 3.00e-04
# 2026-03-21 17:26:34 — src.models.train_nn — INFO — Epoch 025 | Loss: 0.3281 | Train AUC: 0.9206 | Test AUC: 0.9183 | AUC-PR: 0.4635 | Brier: 0.0679 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 025 | Loss: 0.3281 | Train AUC: 0.9206 | Test AUC: 0.9183 | AUC-PR: 0.4635 | Brier: 0.0679 | LR: 3.00e-04
# 2026-03-21 17:26:34 — src.models.train_nn — INFO —   -> New best AUC: 0.9183 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9183 (saved)
# 2026-03-21 17:27:27 — src.models.train_nn — INFO — Epoch 026 | Loss: 0.3281 | Train AUC: 0.9206 | Test AUC: 0.9183 | AUC-PR: 0.4637 | Brier: 0.0660 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 026 | Loss: 0.3281 | Train AUC: 0.9206 | Test AUC: 0.9183 | AUC-PR: 0.4637 | Brier: 0.0660 | LR: 3.00e-04
# 2026-03-21 17:27:27 — src.models.train_nn — INFO —   -> New best AUC: 0.9183 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9183 (saved)
# 2026-03-21 17:28:20 — src.models.train_nn — INFO — Epoch 027 | Loss: 0.3278 | Train AUC: 0.9208 | Test AUC: 0.9184 | AUC-PR: 0.4642 | Brier: 0.0646 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 027 | Loss: 0.3278 | Train AUC: 0.9208 | Test AUC: 0.9184 | AUC-PR: 0.4642 | Brier: 0.0646 | LR: 3.00e-04
# 2026-03-21 17:28:20 — src.models.train_nn — INFO —   -> New best AUC: 0.9184 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9184 (saved)
# 2026-03-21 17:29:13 — src.models.train_nn — INFO — Epoch 028 | Loss: 0.3279 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0638 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 028 | Loss: 0.3279 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0638 | LR: 3.00e-04
# 2026-03-21 17:30:08 — src.models.train_nn — INFO — Epoch 029 | Loss: 0.3275 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0646 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 029 | Loss: 0.3275 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0646 | LR: 3.00e-04
# 2026-03-21 17:30:59 — src.models.train_nn — INFO — Epoch 030 | Loss: 0.3273 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0658 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 030 | Loss: 0.3273 | Train AUC: 0.9210 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0658 | LR: 3.00e-04
# 2026-03-21 17:31:50 — src.models.train_nn — INFO — Epoch 031 | Loss: 0.3274 | Train AUC: 0.9212 | Test AUC: 0.9183 | AUC-PR: 0.4637 | Brier: 0.0654 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 031 | Loss: 0.3274 | Train AUC: 0.9212 | Test AUC: 0.9183 | AUC-PR: 0.4637 | Brier: 0.0654 | LR: 3.00e-04
# 2026-03-21 17:32:42 — src.models.train_nn — INFO — Epoch 032 | Loss: 0.3271 | Train AUC: 0.9213 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0653 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 032 | Loss: 0.3271 | Train AUC: 0.9213 | Test AUC: 0.9183 | AUC-PR: 0.4638 | Brier: 0.0653 | LR: 3.00e-04
# 2026-03-21 17:33:38 — src.models.train_nn — INFO — Epoch 033 | Loss: 0.3269 | Train AUC: 0.9214 | Test AUC: 0.9184 | AUC-PR: 0.4646 | Brier: 0.0663 | LR: 3.00e-04
# INFO:src.models.train_nn:Epoch 033 | Loss: 0.3269 | Train AUC: 0.9214 | Test AUC: 0.9184 | AUC-PR: 0.4646 | Brier: 0.0663 | LR: 3.00e-04
# 2026-03-21 17:33:38 — src.models.train_nn — INFO —   -> New best AUC: 0.9184 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9184 (saved)
# 2026-03-21 17:34:31 — src.models.train_nn — INFO — Epoch 034 | Loss: 0.3268 | Train AUC: 0.9215 | Test AUC: 0.9183 | AUC-PR: 0.4642 | Brier: 0.0637 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 034 | Loss: 0.3268 | Train AUC: 0.9215 | Test AUC: 0.9183 | AUC-PR: 0.4642 | Brier: 0.0637 | LR: 1.50e-04
# 2026-03-21 17:35:26 — src.models.train_nn — INFO — Epoch 035 | Loss: 0.3263 | Train AUC: 0.9217 | Test AUC: 0.9183 | AUC-PR: 0.4648 | Brier: 0.0645 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 035 | Loss: 0.3263 | Train AUC: 0.9217 | Test AUC: 0.9183 | AUC-PR: 0.4648 | Brier: 0.0645 | LR: 1.50e-04
# 2026-03-21 17:36:19 — src.models.train_nn — INFO — Epoch 036 | Loss: 0.3261 | Train AUC: 0.9219 | Test AUC: 0.9184 | AUC-PR: 0.4648 | Brier: 0.0653 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 036 | Loss: 0.3261 | Train AUC: 0.9219 | Test AUC: 0.9184 | AUC-PR: 0.4648 | Brier: 0.0653 | LR: 1.50e-04
# 2026-03-21 17:37:12 — src.models.train_nn — INFO — Epoch 037 | Loss: 0.3264 | Train AUC: 0.9219 | Test AUC: 0.9183 | AUC-PR: 0.4649 | Brier: 0.0660 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 037 | Loss: 0.3264 | Train AUC: 0.9219 | Test AUC: 0.9183 | AUC-PR: 0.4649 | Brier: 0.0660 | LR: 1.50e-04
# 2026-03-21 17:38:06 — src.models.train_nn — INFO — Epoch 038 | Loss: 0.3260 | Train AUC: 0.9220 | Test AUC: 0.9183 | AUC-PR: 0.4648 | Brier: 0.0646 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 038 | Loss: 0.3260 | Train AUC: 0.9220 | Test AUC: 0.9183 | AUC-PR: 0.4648 | Brier: 0.0646 | LR: 1.50e-04
# 2026-03-21 17:39:01 — src.models.train_nn — INFO — Epoch 039 | Loss: 0.3259 | Train AUC: 0.9220 | Test AUC: 0.9184 | AUC-PR: 0.4651 | Brier: 0.0653 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 039 | Loss: 0.3259 | Train AUC: 0.9220 | Test AUC: 0.9184 | AUC-PR: 0.4651 | Brier: 0.0653 | LR: 1.50e-04
# 2026-03-21 17:39:01 — src.models.train_nn — INFO —   -> New best AUC: 0.9184 (saved)
# INFO:src.models.train_nn:  -> New best AUC: 0.9184 (saved)
# 2026-03-21 17:39:57 — src.models.train_nn — INFO — Epoch 040 | Loss: 0.3256 | Train AUC: 0.9221 | Test AUC: 0.9183 | AUC-PR: 0.4650 | Brier: 0.0658 | LR: 1.50e-04
# INFO:src.models.train_nn:Epoch 040 | Loss: 0.3256 | Train AUC: 0.9221 | Test AUC: 0.9183 | AUC-PR: 0.4650 | Brier: 0.0658 | LR: 1.50e-04
# 2026-03-21 17:40:53 — src.models.train_nn — INFO — Epoch 041 | Loss: 0.3262 | Train AUC: 0.9222 | Test AUC: 0.9184 | AUC-PR: 0.4652 | Brier: 0.0639 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 041 | Loss: 0.3262 | Train AUC: 0.9222 | Test AUC: 0.9184 | AUC-PR: 0.4652 | Brier: 0.0639 | LR: 7.50e-05
# 2026-03-21 17:41:46 — src.models.train_nn — INFO — Epoch 042 | Loss: 0.3255 | Train AUC: 0.9223 | Test AUC: 0.9184 | AUC-PR: 0.4650 | Brier: 0.0644 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 042 | Loss: 0.3255 | Train AUC: 0.9223 | Test AUC: 0.9184 | AUC-PR: 0.4650 | Brier: 0.0644 | LR: 7.50e-05
# 2026-03-21 17:42:41 — src.models.train_nn — INFO — Epoch 043 | Loss: 0.3255 | Train AUC: 0.9223 | Test AUC: 0.9183 | AUC-PR: 0.4650 | Brier: 0.0644 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 043 | Loss: 0.3255 | Train AUC: 0.9223 | Test AUC: 0.9183 | AUC-PR: 0.4650 | Brier: 0.0644 | LR: 7.50e-05
# 2026-03-21 17:43:33 — src.models.train_nn — INFO — Epoch 044 | Loss: 0.3252 | Train AUC: 0.9224 | Test AUC: 0.9184 | AUC-PR: 0.4653 | Brier: 0.0651 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 044 | Loss: 0.3252 | Train AUC: 0.9224 | Test AUC: 0.9184 | AUC-PR: 0.4653 | Brier: 0.0651 | LR: 7.50e-05
# 2026-03-21 17:44:26 — src.models.train_nn — INFO — Epoch 045 | Loss: 0.3254 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4653 | Brier: 0.0645 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 045 | Loss: 0.3254 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4653 | Brier: 0.0645 | LR: 7.50e-05
# 2026-03-21 17:45:18 — src.models.train_nn — INFO — Epoch 046 | Loss: 0.3254 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4652 | Brier: 0.0645 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 046 | Loss: 0.3254 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4652 | Brier: 0.0645 | LR: 7.50e-05
# 2026-03-21 17:46:10 — src.models.train_nn — INFO — Epoch 047 | Loss: 0.3252 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4654 | Brier: 0.0642 | LR: 7.50e-05
# INFO:src.models.train_nn:Epoch 047 | Loss: 0.3252 | Train AUC: 0.9225 | Test AUC: 0.9183 | AUC-PR: 0.4654 | Brier: 0.0642 | LR: 7.50e-05
# 2026-03-21 17:47:02 — src.models.train_nn — INFO — Epoch 048 | Loss: 0.3254 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4651 | Brier: 0.0651 | LR: 3.75e-05
# INFO:src.models.train_nn:Epoch 048 | Loss: 0.3254 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4651 | Brier: 0.0651 | LR: 3.75e-05
# 2026-03-21 17:47:51 — src.models.train_nn — INFO — Epoch 049 | Loss: 0.3248 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4653 | Brier: 0.0642 | LR: 3.75e-05
# INFO:src.models.train_nn:Epoch 049 | Loss: 0.3248 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4653 | Brier: 0.0642 | LR: 3.75e-05
# 2026-03-21 17:48:43 — src.models.train_nn — INFO — Epoch 050 | Loss: 0.3254 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4652 | Brier: 0.0643 | LR: 3.75e-05
# INFO:src.models.train_nn:Epoch 050 | Loss: 0.3254 | Train AUC: 0.9226 | Test AUC: 0.9183 | AUC-PR: 0.4652 | Brier: 0.0643 | LR: 3.75e-05
# 2026/03/21 17:48:53 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# 2026/03/21 17:48:53 WARNING mlflow.utils.requirements_utils: Found torch version (2.5.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.5.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/03/21 17:49:00 WARNING mlflow.utils.requirements_utils: Found torch version (2.5.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.5.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026-03-21 17:49:00 — src.models.train_nn — INFO — NN training complete. Best AUC-ROC: 0.9184
# INFO:src.models.train_nn:NN training complete. Best AUC-ROC: 0.9184

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

xgb_probs = pd.read_parquet("data/outputs/xgb_predictions.parquet")["y_prob_xgb"].values
nn_probs  = pd.read_parquet("data/outputs/nn_predictions.parquet")["y_prob_nn"].values
y_test    = pd.read_parquet("data/outputs/y_test.parquet").values.ravel()

corr = np.corrcoef(xgb_probs, nn_probs)[0, 1]
print(f"XGB vs NN correlation : {corr:.4f}")

# Try weighted blends
for w in [0.3, 0.4, 0.5, 0.6, 0.7]:
    blend = w * xgb_probs + (1 - w) * nn_probs
    auc   = roc_auc_score(y_test, blend)
    print(f"  XGB weight {w:.1f} → Ensemble AUC: {auc:.4f}")
# Out:
# XGB vs NN correlation : 0.9710
#   XGB weight 0.3 → Ensemble AUC: 0.9187
#   XGB weight 0.4 → Ensemble AUC: 0.9186
#   XGB weight 0.5 → Ensemble AUC: 0.9186
#   XGB weight 0.6 → Ensemble AUC: 0.9185
#   XGB weight 0.7 → Ensemble AUC: 0.9183

# %%
from src.utils.config import load_config, get_project_root
from pathlib import Path
from sklearn.metrics import roc_auc_score, f1_score
from scipy.stats import chi2
import numpy as np
import pandas as pd

# ── Define output_dir ─────────────────────────────────────────
config     = load_config()
output_dir = Path(get_project_root()) / config["paths"]["outputs"]

y_test    = pd.read_parquet(output_dir / "y_test.parquet").squeeze().values
xgb_probs = pd.read_parquet(output_dir / "xgb_predictions.parquet")["y_prob_xgb"].values
nn_probs  = pd.read_parquet(output_dir / "nn_predictions.parquet")["y_prob_nn"].values

# ── McNemar's Test ────────────────────────────────────────────
thresholds = np.linspace(0.01, 0.99, 200)
def best_threshold(probs, y):
    scores = [f1_score(y, probs >= t, zero_division=0) for t in thresholds]
    return thresholds[np.argmax(scores)]

thresh_xgb = best_threshold(xgb_probs, y_test)
thresh_nn  = best_threshold(nn_probs,  y_test)
pred_xgb   = (xgb_probs >= thresh_xgb).astype(int)
pred_nn    = (nn_probs  >= thresh_nn).astype(int)

n01 = ((pred_xgb == 0) & (pred_nn == 1) & (y_test == 1)).sum()
n10 = ((pred_xgb == 1) & (pred_nn == 0) & (y_test == 1)).sum()
mcnemar_stat = (abs(n01 - n10) - 1) ** 2 / (n01 + n10)
p_value = 1 - chi2.cdf(mcnemar_stat, df=1)
print(f"McNemar: stat={mcnemar_stat:.4f} | p={p_value:.6f} | n01={n01} | n10={n10}")

# ── Bootstrap CI ─────────────────────────────────────────────
rng = np.random.default_rng(42)
diffs = []
for _ in range(1000):
    idx = rng.integers(0, len(y_test), len(y_test))
    diffs.append(
        roc_auc_score(y_test[idx], nn_probs[idx]) -
        roc_auc_score(y_test[idx], xgb_probs[idx])
    )
ci_low, ci_high = np.percentile(diffs, [2.5, 97.5])
print(f"Bootstrap 95% CI (NN - XGB): [{ci_low:.4f}, {ci_high:.4f}]")
print(f"Winner: {'NN' if ci_low > 0 else 'XGB' if ci_high < 0 else 'No significant difference'}")
# Out:
# McNemar: stat=194.7552 | p=0.000000 | n01=1154 | n10=1930
# Bootstrap 95% CI (NN - XGB): [0.0006, 0.0011]
# Winner: NN

# %%
import shap
import xgboost as xgb
import pandas as pd
import numpy as np
from pathlib import Path

X_test = pd.read_parquet(output_dir / "X_test.parquet")

# Load the saved XGBoost model
model = xgb.XGBClassifier()
model.load_model(str(output_dir / "xgb_model.json"))

# TreeExplainer — exact SHAP values, fast on XGBoost
explainer   = shap.TreeExplainer(model)
shap_values = explainer(X_test)          # full 360K rows, ~2–3 min

# Save for Model 2 dataset generation later
np.save(output_dir / "shap_values.npy", shap_values.values)
print(f"SHAP values shape: {shap_values.values.shape}")  # (360457, 60)

# Global beeswarm — top 20 features
shap.plots.beeswarm(shap_values, max_display=20)
# Out:
# SHAP values shape: (540686, 60)

# %%
from src.utils.config import load_config, get_project_root
from pathlib import Path
import pandas as pd
import numpy as np
import shap
import xgboost as xgb
import matplotlib.pyplot as plt

config     = load_config()
output_dir = Path(get_project_root()) / config["paths"]["outputs"]

# ── Load everything from disk — NO recomputation ──────────────
X_test          = pd.read_parquet(output_dir / "X_test.parquet")
y_test          = pd.read_parquet(output_dir / "y_test.parquet").squeeze().values
shap_values_arr = np.load(output_dir / "shap_values.npy")        # instant load

model = xgb.XGBClassifier()
model.load_model(str(output_dir / "xgb_model.json"))
probs = model.predict_proba(X_test)[:, 1]

# ── Reconstruct shap Explanation object ───────────────────────
explainer   = shap.TreeExplainer(model)
base_value  = explainer.expected_value                            # single float, instant
shap_exp    = shap.Explanation(
    values          = shap_values_arr,
    base_values     = np.full(len(X_test), base_value),
    data            = X_test.values,
    feature_names   = X_test.columns.tolist()
)

# ── Pick 3 loans ──────────────────────────────────────────────
low_idx  = np.where((probs < 0.15) & (y_test == 0))[0][0]
mid_idx  = np.where((probs > 0.35) & (probs < 0.55) & (y_test == 1))[0][0]
high_idx = np.where((probs > 0.75) & (y_test == 1))[0][0]

# ── Waterfall plots — each takes < 1 second ───────────────────
for label, idx in [("low_risk", low_idx), ("medium_risk", mid_idx), ("high_risk", high_idx)]:
    print(f"\n── {label.upper()} | prob={probs[idx]:.3f} | actual={y_test[idx]} ──")
    shap.plots.waterfall(shap_exp[idx], max_display=12, show=False)
    plt.title(f"{label} | predicted probability: {probs[idx]:.3f}")
    plt.tight_layout()
    plt.savefig(output_dir / f"shap_waterfall_{label}.png", dpi=150, bbox_inches="tight")
    plt.show()
# Out:
# ── LOW_RISK | prob=0.042 | actual=0.0 ──
# ── MEDIUM_RISK | prob=0.364 | actual=1.0 ──
# ── HIGH_RISK | prob=0.899 | actual=1.0 ──

# %%
import pandas as pd
import numpy as np
from scipy import stats

X_train = pd.read_parquet(output_dir / "X_train.parquet")
X_test  = pd.read_parquet(output_dir / "X_test.parquet")

def compute_psi(train_col, test_col, bins=10):
    breakpoints = np.percentile(train_col, np.linspace(0, 100, bins + 1))
    breakpoints = np.unique(breakpoints)
    if len(breakpoints) < 3:
        return 0.0
    train_counts = np.histogram(train_col, bins=breakpoints)[0] / len(train_col)
    test_counts  = np.histogram(test_col,  bins=breakpoints)[0] / len(test_col)
    train_counts = np.where(train_counts == 0, 1e-6, train_counts)
    test_counts  = np.where(test_counts  == 0, 1e-6, test_counts)
    return np.sum((test_counts - train_counts) * np.log(test_counts / train_counts))

results = []
for col in X_train.columns:
    psi = compute_psi(X_train[col].dropna(), X_test[col].dropna())
    ks_stat, ks_p = stats.ks_2samp(X_train[col].dropna(), X_test[col].dropna())
    results.append({
        "feature": col,
        "psi":     round(psi, 4),
        "ks_stat": round(ks_stat, 4),
        "ks_pval": round(ks_p, 6),
        "drift_flag": "🚨 HIGH" if psi > 0.2 else ("⚠️ MODERATE" if psi > 0.1 else "✅ STABLE")
    })

drift_df = pd.DataFrame(results).sort_values("psi", ascending=False)
drift_df.to_csv(output_dir / "drift_report.csv", index=False)

print(drift_df.head(20).to_string(index=False))
print(f"\nFeatures flagged HIGH drift (PSI>0.2): {(drift_df['psi']>0.2).sum()}")
print(f"Features flagged MODERATE drift:       {((drift_df['psi']>0.1) & (drift_df['psi']<=0.2)).sum()}")
print(f"Features STABLE (PSI<0.1):             {(drift_df['psi']<0.1).sum()}")
# Out:
#                feature  psi  ks_stat  ks_pval drift_flag
#         logfunded_amnt  0.0   0.0013 0.444467   ✅ STABLE
#               int_rate  0.0   0.0010 0.754244   ✅ STABLE
#            installment  0.0   0.0014 0.406626   ✅ STABLE
#         inq_last_6mths  0.0   0.0006 0.999088   ✅ STABLE
#               open_acc  0.0   0.0012 0.539649   ✅ STABLE
#           logtotal_acc  0.0   0.0012 0.602395   ✅ STABLE
#                pub_rec  0.0   0.0004 1.000000   ✅ STABLE
#             des_length  0.0   0.0002 1.000000   ✅ STABLE
#      logpct_tl_nvr_dlq  0.0   0.0007 0.983174   ✅ STABLE
#     logtot_hi_cred_lim  0.0   0.0012 0.612589   ✅ STABLE
#             revol_util  0.0   0.0009 0.841058   ✅ STABLE
#              revol_bal  0.0   0.0013 0.426188   ✅ STABLE
#            delinq_2yrs  0.0   0.0004 1.000000   ✅ STABLE
# mths_since_last_delinq  0.0   0.0011 0.718846   ✅ STABLE
#  mths_since_recent_inq  0.0   0.0010 0.768894   ✅ STABLE
#   mths_since_recent_bc  0.0   0.0013 0.503629   ✅ STABLE
#   acc_open_past_24mths  0.0   0.0010 0.818598   ✅ STABLE
#               mort_acc  0.0   0.0007 0.987119   ✅ STABLE
#   pub_rec_bankruptcies  0.0   0.0002 1.000000   ✅ STABLE
#              tax_liens  0.0   0.0004 0.999999   ✅ STABLE
#
# Features flagged HIGH drift (PSI>0.2): 0
# Features flagged MODERATE drift:       0
# Features STABLE (PSI<0.1):             60

# %%
import joblib, pandas as pd
X_test = pd.read_parquet("../data/outputs/X_test.parquet")
joblib.dump(list(X_test.columns), "../deploy/artifacts/feature_cols.joblib")
# Out:
# ['../deploy/artifacts/feature_cols.joblib']

# %%
pd.read_parquet("../data/outputs/X_test.parquet").columns.tolist()
# Out:
# ['logfunded_amnt',
#  'int_rate',
#  'installment',
#  'inq_last_6mths',
#  'open_acc',
#  'logtotal_acc',
#  'pub_rec',
#  'des_length',
#  'logpct_tl_nvr_dlq',
#  'logtot_hi_cred_lim',
#  'revol_util',
#  'revol_bal',
#  'delinq_2yrs',
#  'mths_since_last_delinq',
#  'mths_since_recent_inq',
#  'mths_since_recent_bc',
#  'acc_open_past_24mths',
#  'mort_acc',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'acc_now_delinq',
#  'num_tl_90g_dpd_24m',
#  'pct_tl_nvr_dlq',
#  'tot_cur_bal',
#  'avg_cur_bal',
#  'bc_util',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'logannual_inc',
#  'logdti',
#  'emp_length_',
#  'home_ownership_',
#  'verification_status_',
#  'muni_6m_resid',
#  'FED_lag6_resid',
#  'CPIUS_resid',
#  'FEDFUNDS_resid',
#  'inf_resid',
#  'inf_6m_resid',
#  'muni_points_resid',
#  'riskprem_resid',
#  'cpi_resid',
#  'logunemployment_resid',
#  'logearnings_resid',
#  'gdpcontrib_resid',
#  'loglabor_force',
#  'logempl_birth',
#  'lognew_bus',
#  'loginternetuser',
#  'grade_',
#  'term_',
#  'purpose_',
#  'application_type_',
#  'initial_list_status_',
#  'issue_year',
#  'dti_x_unemployment',
#  'real_interest_rate',
#  'loan_to_income',
#  'util_x_delinq',
#  'fed_x_term']
